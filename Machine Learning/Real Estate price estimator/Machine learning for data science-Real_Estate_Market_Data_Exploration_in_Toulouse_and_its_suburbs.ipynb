# %% [markdown]
# <font color="dark blue">Real World Uses Cases Project: Big Data Tools for Business
#
# ---
# # Part 2: Real Estate Market Data Exploration in Toulouse and its suburbs
#
# ---
# <font color="grey">*Léa DIAMBUANA, Assa FISSIROU, Mehdi BALOUKA*

# %% [markdown]
# ##Part 1 : Setting spark environment on google colabs

# %%
# For installing PySpark
# !pip install pyspark==3.0.0
# Out:
# Collecting pyspark==3.0.0
#   Downloading pyspark-3.0.0.tar.gz (204.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.7/204.7 MB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9 (from pyspark==3.0.0)
#   Downloading py4j-0.10.9-py2.py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 15.7 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.0.0-py2.py3-none-any.whl size=205044160 sha256=4e5e181027cddcb7500e6a0e6963e25af2ad2a5b422c4f2963cbd05eeed15ca3
#   Stored in directory: /root/.cache/pip/wheels/b1/bb/8b/ca24d3f756f2ed967225b0871898869db676eb5846df5adc56
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.7
#     Uninstalling py4j-0.10.9.7:
#       Successfully uninstalled py4j-0.10.9.7
# Successfully installed py4j-0.10.9 pyspark-3.0.0

# %%
# Mount your Google Drive to be able to access files from your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("Spark-Dataframe-SQL-real-estate") \
    .getOrCreate()

# Get the SparkContext
sc = spark.sparkContext

# %% [markdown]
# *Setting the packages for analyses*

# %%
# Spark MLib is included as part of Pyspark

# !pip install pyspark==3.0.0 matplotlib

import pandas as pd
import numpy as np
import re
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
from collections import defaultdict
import seaborn as sns
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType
# Out:
# Requirement already satisfied: pyspark==3.0.0 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: py4j==0.10.9 in /usr/local/lib/python3.10/dist-packages (from pyspark==3.0.0) (0.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # Read and Parse the CSV File

# %% [markdown]
# #### Schema Definition for Real Estate Data

# %%
# The schema must be defined using DataTypes from pyspark.sql.types
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType

dfSchema = StructType([
    StructField("SaleDate", StringType(), False),  # Date column - Change data type to StringType as we were facing issues
    StructField("SaleType", StringType(), False),
    StructField("Price", IntegerType(), False),
    StructField("PostCode", StringType(), False),
    StructField("City", StringType(), False),
    StructField("NbRooms", IntegerType(), False),
    StructField("NbLots", IntegerType(), False),
    StructField("ResidenceType", StringType(), False),
    StructField("LivingArea", IntegerType(), False),
    StructField("LandArea", IntegerType(), False)])

# %% [markdown]
# Load the CSV data into a DataFrame, considering the semicolon delimiter.

# %%
 # Assa's path
real_estate_df = spark.read.option("delimiter", ";").csv('drive/MyDrive/AIBA Big data Analytics/PYSPARK-COURSE/Project/Real Estate/project_data_real_estate_toulouse_and_suburbs.csv', header=True, schema=dfSchema, dateFormat="yyyy-MM-dd")

# Convert the SaleDate to a DateType using the to_date() function
from pyspark.sql.functions import to_date
real_estate_df = real_estate_df.withColumn("SaleDate", to_date(real_estate_df["SaleDate"], "dd/MM/yyyy"))

real_estate_df.show()
# Out:
# +----------+--------------------+------+--------+-------------------+-------+------+-------------+----------+--------+
# |  SaleDate|            SaleType| Price|PostCode|               City|NbRooms|NbLots|ResidenceType|LivingArea|LandArea|
# +----------+--------------------+------+--------+-------------------+-------+------+-------------+----------+--------+
# |2019-01-15|                SALE| 95000|   31270|VILLENEUVE TOLOSANE|      2|     0|        HOUSE|        45|     505|
# |2019-01-21|                SALE|261700|   31270|VILLENEUVE TOLOSANE|      4|     0|        HOUSE|        87|     311|
# |2019-01-03|                SALE|101000|   31270|VILLENEUVE TOLOSANE|      2|     1|    APARTMENT|        44|       0|
# |2019-01-11|                SALE| 59500|   31270|VILLENEUVE TOLOSANE|      1|     1|    APARTMENT|        26|       0|
# |2019-01-15|                SALE|179000|   31270|VILLENEUVE TOLOSANE|      4|     0|        HOUSE|        95|     263|
# |2019-01-15|                SALE|209300|   31270|VILLENEUVE TOLOSANE|      4|     0|        HOUSE|        74|     257|
# |2019-01-18|                SALE|228000|   31270|VILLENEUVE TOLOSANE|      4|     0|        HOUSE|        95|     268|
# |2019-01-16|SALE BEFORE COMPL...|214300|   31270|VILLENEUVE TOLOSANE|      3|     0|        HOUSE|        66|     164|
# |2019-01-17|                SALE|306000|   31270|VILLENEUVE TOLOSANE|      5|     0|        HOUSE|       157|     763|
# |2019-01-29|                SALE|269000|   31270|VILLENEUVE TOLOSANE|      5|     0|        HOUSE|       100|     855|
# |2019-02-07|                SALE|  null|   31270|VILLENEUVE TOLOSANE|      3|     1|    APARTMENT|        64|       0|
# |2019-02-07|                SALE|220000|   31270|VILLENEUVE TOLOSANE|      4|     0|        HOUSE|        84|     484|
# |2019-04-12|                SALE|300000|   31270|VILLENEUVE TOLOSANE|      3|     0|        HOUSE|       100|     467|
# |2019-04-12|                SALE|300000|   31270|VILLENEUVE TOLOSANE|      3|     0|        HOUSE|       100|    1526|
# |2018-01-10|                SALE|215000|   31270|VILLENEUVE TOLOSANE|      4|     0|        HOUSE|        84|     107|
# |2019-01-10|                SALE|395400|   31130|  QUINT-FONSEGRIVES|      5|     0|        HOUSE|       155|     802|
# |2018-01-18|                SALE|200000|   31270|VILLENEUVE TOLOSANE|      4|     0|        HOUSE|       105|     500|
# |2018-01-05|                SALE|332000|   31270|VILLENEUVE TOLOSANE|      5|     0|        HOUSE|       140|     969|
# |2018-01-08|                SALE|123000|   31270|VILLENEUVE TOLOSANE|      3|     1|    APARTMENT|        56|       0|
# |2018-01-26|                SALE|107000|   31270|VILLENEUVE TOLOSANE|      2|     1|    APARTMENT|        47|       0|
# +----------+--------------------+------+--------+-------------------+-------+------+-------------+----------+--------+
# only showing top 20 rows

# %% [markdown]
# ## EDA - Exploratory Data Analysis on Real Estate Data

# %% [markdown]
# Display the shape, schema, and statistical summary of the real estate DataFrame

# %%
# Exploratory Data Analysis on Real Estate Data
print("Exploratory Data Analysis on Real Estate Data:")

# Calculate the shape of the DataFrame
print("\nDataFrame shape:")
print("Rows:", real_estate_df.count(), "Columns:", len(real_estate_df.columns))

# Print the schema of the DataFrame
print("\nDataFrame schema:")
real_estate_df.printSchema()
# Out:
# Exploratory Data Analysis on Real Estate Data:
#
# DataFrame shape:
# Rows: 80118 Columns: 10
#
# DataFrame schema:
# root
#  |-- SaleDate: date (nullable = true)
#  |-- SaleType: string (nullable = true)
#  |-- Price: integer (nullable = true)
#  |-- PostCode: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- NbRooms: integer (nullable = true)
#  |-- NbLots: integer (nullable = true)
#  |-- ResidenceType: string (nullable = true)
#  |-- LivingArea: integer (nullable = true)
#  |-- LandArea: integer (nullable = true)

# %%
# Select the specific columns of interest
columns_for_EDA = ["Price", "LivingArea", "LandArea", "NbRooms", "NbLots"]

# Display statistical summary for selected columns relevant to EDA
print("\nStatistical summary for selected columns:")
real_estate_df.select(columns_for_EDA).describe().show()
# Out:
# Statistical summary for selected columns:
# +-------+-----------------+------------------+------------------+------------------+------------------+
# |summary|            Price|        LivingArea|          LandArea|           NbRooms|            NbLots|
# +-------+-----------------+------------------+------------------+------------------+------------------+
# |  count|            77105|             80118|             80118|             80118|             80118|
# |   mean|552147.5415342714| 66.89275818168201|254.02662323073466| 3.000099852717242|1.0370453580968073|
# | stddev|2435569.995421839|35.895209994602894|1369.2367598573917|1.3511218124829423|0.8291382225291016|
# |    min|                0|                 1|                 0|                 1|                 0|
# |    max|         33427218|               481|             60792|                41|                13|
# +-------+-----------------+------------------+------------------+------------------+------------------+

# %% [markdown]
# ### Calculate and display the evolution of price per square meter

# %%
import pyspark.sql.functions as f

price_evolution = real_estate_df.groupBy('SaleDate')\
    .agg((f.sum('Price') / f.sum('LivingArea')).alias('Price_square'))\
    .orderBy('SaleDate')

# Show the first few records of the price evolution
print("First few records of the price evolution:")
price_evolution.show(7)

# Convert to Pandas DataFrame for visualization
pandas_df = price_evolution.toPandas()
# Out:
# First few records of the price evolution:
# +----------+------------------+
# |  SaleDate|      Price_square|
# +----------+------------------+
# |2015-01-02|2453.1052631578946|
# |2015-01-03| 2089.887640449438|
# |2015-01-04| 3418.803418803419|
# |2015-01-05|2567.3167777104786|
# |2015-01-06| 2919.534515277254|
# |2015-01-07| 5187.600485240599|
# |2015-01-08| 6485.476973684211|
# +----------+------------------+
# only showing top 7 rows

# %% [markdown]
# ## Line Plot for Price Evolution Over Time
# Visualize the trend of price per square meter over time

# %%
# Create a line plot
plt.figure(figsize=(20, 7))
sns.lineplot(x='SaleDate', y='Price_square', data=pandas_df)

# Set a title for the plot
plt.title('Price Evolution Over Time')

# Set labels for the plot
plt.xlabel('Sale Date')
plt.ylabel('Price per Square')

# Show the plot
plt.show()

# %% [markdown]
# **Outliers in the price evolution**
#
# We can observe some outliers in the price per square meter exceeding 50,000 in certain periods. These outliers are significant as they can indicate unique properties or errors in the data.
#
# To ensure the integrity of our analysis, we will exclude outliers over the 98th quartile from our detailed analysis (2%), although these outliers could be interesting for a separate investigation.
#
# Real estate prices can vary significantly depending on the area, and extreme values are not uncommon.
#
# **Then, let's analyze the differences between residence types: Houses and Apartments. **
#
# After conducting research, we've decided to employ a weighted approach to calculate the combined price per square meter,  considering the relative value of living space versus land area. This approach accounts for factors
# such as location, zoning regulations, and development potential, using the formula:
#
# **Combined Price per m² = Price of Property / (Living Area in m² + Land Area in m²). **

# %% [markdown]
# ### Identify & Remove Outliers

# %%
# Calculate the 99th percentile for the 'Price' column
quantile_99 = real_estate_df.stat.approxQuantile("Price", [0.99], 0.01)

# quantile_99 will contain one value: the 98.5th percentile of the 'Price' column
upper_bound = quantile_99[0]

# Now you can filter your DataFrame to exclude prices above this upper bound
real_estate_df = real_estate_df.filter(real_estate_df["Price"] <= upper_bound)

# %% [markdown]
# The **approxQuantile method** is used to find the 98th percentile for the Price column with a relativeError of 0.01, providing a balance between accuracy and computational efficiency.
#
# The upper_bound is then used as a threshold to filter out any rows in the DataFrame where the Price exceeds this value.
#
# This way, you ensure that our analysis focuses on the majority of the data and is not skewed by a few extreme outliers.

# %%
# Calculate the combined price per square meter for houses
house_price_evolution = filtered_real_estate_df.filter(filtered_real_estate_df['ResidenceType'] == 'HOUSE') \
    .groupBy('SaleDate') \
    .agg((f.sum('Price') / (f.sum('LivingArea') + f.sum('LandArea'))).alias('Price_per_m2')) \
    .orderBy('SaleDate')

# Calculate the combined price per square meter for apartments
apartment_price_evolution = filtered_real_estate_df.filter(filtered_real_estate_df['ResidenceType'] == 'APARTMENT') \
    .groupBy('SaleDate') \
    .agg((f.sum('Price') / (f.sum('LivingArea') + f.sum('LandArea'))).alias('Price_per_m2')) \
    .orderBy('SaleDate')

# Create line plots for houses and apartments using Matplotlib and Seaborn
plt.figure(figsize=(13, 7))

# Plot for houses
sns.lineplot(x='SaleDate', y='Price_per_m2', data=house_price_evolution.toPandas(), label='Houses')

# Plot for apartments
sns.lineplot(x='SaleDate', y='Price_per_m2', data=apartment_price_evolution.toPandas(), label='Apartments')

plt.title('Price Evolution Over Time (Excluding Outliers)')
plt.xlabel('Sale Date')
plt.ylabel('Price per Square Meter')
plt.legend()
plt.show()

# %% [markdown]
# The plot illustrates the price evolution over time for houses and apartments,
#  excluding outliers with a price per square meter exceeding 50k.
#
# It shows that houses generally have higher prices per square meter compared to apartments, which can be attributed to factors such as larger living space, land ownership, privacy, location, demand and supply dynamics, among others.
#
# Let's analyse price per city!

# %% [markdown]
# # Average price per city

# %%
# Sort the DataFrame ascendingly
average_price_per_city_df.sort_values('avg_Price', ascending=False, inplace=True)

# Compute the average price per city
average_price_per_city = real_estate_df.groupBy('City')\
                                       .agg(f.avg('Price').alias('avg_Price'))\
                                       .orderBy('avg_Price', ascending=False)

# Convert the result to Pandas DataFrame for plotting
average_price_per_city_df = average_price_per_city.toPandas()

# Plotting the overall average price per city
plt.figure(figsize=(20, 10))
barplot = sns.barplot(x='City', y='avg_Price', data=average_price_per_city_df, palette='Blues_r')

# Set labels and title
plt.xticks(rotation=45)  # Rotate labels to avoid overlap
plt.xlabel('City', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.title('Average Price Per City', fontsize=16)

# Annotate bars with the average price value
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.2f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha = 'center', va = 'center',
                     xytext = (0, 10),
                     textcoords = 'offset points')

# Display the bar plot
plt.show()
# Out:
# <ipython-input-200-f5ec99c9299e>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x='City', y='avg_Price', data=average_price_per_city_df, palette='Blues_r')

# %% [markdown]
# To have a simpler view, we will display just the 10 cities where houses and apartments are expensive.

# %%
# Plotting the top 10 cities by average price
plt.figure(figsize=(20, 10))
top_cities_barplot = sns.barplot(x='City', y='avg_Price', data=average_price_per_city_df.head(10), palette='Blues_r')

# Set labels and title
plt.xticks(rotation=45)
plt.xlabel('City', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.title('Top 10 Cities by Average Price', fontsize=16)

# Annotate bars with the average price value for top cities
for p in top_cities_barplot.patches:
    top_cities_barplot.annotate(format(p.get_height(), '.2f'),
                                (p.get_x() + p.get_width() / 2., p.get_height()),
                                ha = 'center', va = 'center',
                                xytext = (0, 10),
                                textcoords = 'offset points')

# Display the bar plot
plt.show()
# Out:
# <ipython-input-201-994897204267>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   top_cities_barplot = sns.barplot(x='City', y='avg_Price', data=average_price_per_city_df.head(10), palette='Blues_r')

# %% [markdown]
# Interpretation:
#
# From this graph we can notice the variation of the price of square meter in each part of Toulouse, For Vieille Toulouse and Labege we find the highest price per square meter.
#
# Important note:
#
# We have excluding 1% of highest value, we can reproduce this computation without excluding 1% of these "outliers" even if that is a minority of observations.

# %% [markdown]
# ## House Analysis

# %%
# Compute the average price per total square meter for houses
average_price_per_total_square_meter_house = real_estate_df.filter(real_estate_df['ResidenceType'] == 'HOUSE') \
    .groupBy('City') \
    .agg((f.avg('Price') / (f.avg('LivingArea') + f.avg('LandArea'))).alias('avg_Price_per_total_square_meter')) \
    .orderBy('avg_Price_per_total_square_meter', ascending=False)

# Convert the result to a Pandas DataFrame for plotting
average_price_per_total_square_meter_house_df = average_price_per_total_square_meter_house.toPandas()

# Create a bar plot with a blue color palette
plt.figure(figsize=(20, 7))
sns.barplot(x='City', y='avg_Price_per_total_square_meter', data=average_price_per_total_square_meter_house_df, palette='Blues_r')

# Set labels and title
plt.xlabel('City')
plt.ylabel('Average Price per Total Square Meter (HOUSE)')
plt.title('Average Price per Total Square Meter for Houses')

# Display the bar plot
plt.show()
# Out:
# <ipython-input-202-9da5c37f76c5>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City', y='avg_Price_per_total_square_meter', data=average_price_per_total_square_meter_house_df, palette='Blues_r')

# %%
# Plotting the top 10 most expensive houses
plt.figure(figsize=(20, 7))
sns.barplot(x='City', y='avg_Price_per_total_square_meter', data=average_price_per_total_square_meter_house_df.head(10), palette='Blues_r')

# Set labels and title
plt.xlabel('City')
plt.ylabel('Average Price per Total Square Meter (HOUSE)')
plt.title('Top 10 Most Expensive Houses by Average Price per Total Square Meter')

# Display the bar plot
plt.show()
# Out:
# <ipython-input-203-007d934ab9aa>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City', y='avg_Price_per_total_square_meter', data=average_price_per_total_square_meter_house_df.head(10), palette='Blues_r')

# %% [markdown]
# We calculated the total area of each house as the sum of its living area and land area.
#
# This aggregate measure allowed us to allocate the price of the house proportionally to its living and land components, generating two metrics: **Weighted_Living_Area_Price and Weighted_Land_Area_Price.**
#
# These weighted prices reflect the relative value of living spaces and land in the overall price of a house. The computation was performed for each property in our dataset, and average values were aggregated by city.
# This analysis was then visualized for the top 10 cities, offering insights into how different urban areas value living versus land space in residential properties.

# %%
# Calculate price per square meter for living area and land area
real_estate_df = real_estate_df.withColumn("Price_Per_Sq_M_Living", real_estate_df["Price"] / real_estate_df["LivingArea"])
real_estate_df = real_estate_df.withColumn("Price_Per_Sq_M_Land", real_estate_df["Price"] / real_estate_df["LandArea"])

# Aggregate these prices by city for houses, focusing on the highest average prices
average_prices_per_city_house = real_estate_df.filter(real_estate_df['ResidenceType'] == 'HOUSE')\
    .groupBy('City')\
    .agg(f.avg("Price_Per_Sq_M_Living").alias("Avg_Price_Per_Sq_M_Living"),
         f.avg("Price_Per_Sq_M_Land").alias("Avg_Price_Per_Sq_M_Land"))\
    .orderBy("Avg_Price_Per_Sq_M_Living", ascending=False)  # Ensure we're capturing the highest values

# Select the top 10 cities with the highest average price per square meter for living areas
top_10_cities_house = average_prices_per_city_house.limit(10)

# Convert to Pandas DataFrame for plotting
top_10_cities_house_pd = top_10_cities_house.toPandas()

# Visualization for the top 10 most expensive houses by average price per square meter
plt.figure(figsize=(20, 10))
sns.barplot(x="City", y="Avg_Price_Per_Sq_M_Living", data=top_10_cities_house_pd, label="Living Area", color="green")
sns.barplot(x="City", y="Avg_Price_Per_Sq_M_Land", data=top_10_cities_house_pd, label="Land Area", color="brown", alpha=0.6)

plt.xticks(rotation=45)
plt.xlabel("City")
plt.ylabel("Average Price per Square Meter")
plt.title("Top 10 Cities with the Highest Average Price per Square Meter for Houses")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Balma, Toulouse and Blagnac are the top 3 of most valuable places. The price is very close to others.
#
# But it is interesting to note that at Toulouse, land area is very appreciated compare to other price for living area at Balma or Blagnac - it is the most valuable!

# %% [markdown]
# ## Appartment Analysis

# %% [markdown]
# Let's analysing the price per living area for apartments.

# %%
# Compute the average price per living area for apartments
average_price_per_area_apartment = real_estate_df.filter(real_estate_df['ResidenceType'] == 'APARTMENT') \
    .groupBy('City') \
    .agg((f.avg('Price') / f.avg('LivingArea')).alias('avg_Price_per_area')) \
    .orderBy('avg_Price_per_area', ascending=False)

# Convert the result to a Pandas DataFrame for plotting
average_price_per_area_apartment_df = average_price_per_area_apartment.toPandas()

# Create a bar plot with a blue color palette
plt.figure(figsize=(20, 7))
sns.barplot(x='City', y='avg_Price_per_area', data=average_price_per_area_apartment_df, palette='Blues_r')

# Set labels and title
plt.xlabel('City')
plt.ylabel('Average Price per Living Area (APARTMENT)')
plt.title('Average Price per Living Area for Apartments')

# Display the bar plot
plt.show()
# Out:
# <ipython-input-205-4579d7d525ac>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City', y='avg_Price_per_area', data=average_price_per_area_apartment_df, palette='Blues_r')

# %% [markdown]
# Let's only keep top 10 cities even if Vieille Toulouse is outperforming others.

# %%
# Plotting the top 10 most expensive apartments
plt.figure(figsize=(20, 7))
sns.barplot(x='City', y='avg_Price_per_area', data=average_price_per_area_apartment_df.head(10), palette='Blues_r')

# Set labels and title
plt.xlabel('City')
plt.ylabel('Average Price per Living Area (APARTMENT)')
plt.title('Top 10 Most Expensive Apartments by Average Price per Living Area')
# Out:
# <ipython-input-206-706cdd6993b0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City', y='avg_Price_per_area', data=average_price_per_area_apartment_df.head(10), palette='Blues_r')
# Text(0.5, 1.0, 'Top 10 Most Expensive Apartments by Average Price per Living Area')

# %% [markdown]
# Let's analyse the impact of a extra land area for an apartment on their price:

# %%
# Aggregate these prices by city for apartments, focusing on the highest average prices
average_prices_per_city_apartment = real_estate_df.filter(real_estate_df['ResidenceType'] == 'APARTMENT')\
    .groupBy('City')\
    .agg(f.avg("Price_Per_Sq_M_Living").alias("Avg_Price_Per_Sq_M_Living"),
         f.avg("Price_Per_Sq_M_Land").alias("Avg_Price_Per_Sq_M_Land"))\
    .orderBy("Avg_Price_Per_Sq_M_Living", ascending=False)  # Capturing the highest values for apartments

# Select the top 10 cities with the highest average price per square meter for apartments
top_10_cities_apartment = average_prices_per_city_apartment.limit(10)

# Convert to Pandas DataFrame for plotting
top_10_cities_apartment_pd = top_10_cities_apartment.toPandas()

# Visualization for the top 10 most expensive apartments by average price per square meter
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 10))
# Using more comfortable colors for living area and land area
sns.barplot(x="City", y="Avg_Price_Per_Sq_M_Living", data=top_10_cities_apartment_pd, label="Living Area", color="#ff9999")
sns.barplot(x="City", y="Avg_Price_Per_Sq_M_Land", data=top_10_cities_apartment_pd, label="Land Area", color="#66b3ff", alpha=0.6)

plt.xticks(rotation=45)
plt.xlabel("City")
plt.ylabel("Average Price per Square Meter (APARTMENT)")
plt.title("Top 10 Cities with the Highest Average Price per Square Meter for Apartments")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Again, Vieille Toulouse is valuable compare to others for Apartment & Houses.

# %% [markdown]
# # Apartment vs Houses

# %% [markdown]
# ## Number of Room
# To compare houses and apartments in terms of the average number of rooms, we will aggregate the data to calculate the average number of rooms by residence type. Then, you can visualize this comparison using a bar plot.

# %%
# Aggregate data to calculate the average number of rooms by residence type
number_of_rooms_by_type = real_estate_df.groupBy('ResidenceType')\
                                        .agg(f.avg('NbRooms').alias('avg_NbRooms'))

# For comparison outside Toulouse
number_of_rooms_by_type_excluding_toulouse = real_estate_df.filter(real_estate_df['City'] != 'TOULOUSE')\
                                                           .groupBy('ResidenceType')\
                                                           .agg(f.avg('NbRooms').alias('avg_NbRooms'))

# %% [markdown]
# **Visualization:**

# %%
# Convert Spark DataFrame to Pandas DataFrame for visualization
number_of_rooms_by_type_pd = number_of_rooms_by_type.toPandas()
number_of_rooms_by_type_excluding_toulouse_pd = number_of_rooms_by_type_excluding_toulouse.toPandas()

# Visualization for overall comparison
plt.figure(figsize=(10, 6))
sns.barplot(x='ResidenceType', y='avg_NbRooms', data=number_of_rooms_by_type_pd, palette=['#3498db', '#e74c3c'])
plt.title('Average Number of Rooms by Residence Type')
plt.xlabel('Residence Type')
plt.ylabel('Average Number of Rooms')
plt.show()
# Out:
# <ipython-input-212-faca3952a4be>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='ResidenceType', y='avg_NbRooms', data=number_of_rooms_by_type_pd, palette=['#3498db', '#e74c3c'])

# %% [markdown]
# **Comparaison per city:**

# %%
from pyspark.sql.functions import col, round

# Adjusting the aggregation to round the average number of rooms to 2 decimal places
avg_rooms_per_city = real_estate_df.groupBy('City', 'ResidenceType')\
                                   .agg(round(f.avg('NbRooms'), 2).alias('AvgNbRooms'))\
                                   .groupBy('City')\
                                   .pivot('ResidenceType')\
                                   .agg(f.first('AvgNbRooms'))

# Showing the DataFrame (in Spark)
avg_rooms_per_city.show()
# Out:
# +--------------------+---------+-----+
# |                City|APARTMENT|HOUSE|
# +--------------------+---------+-----+
# |             BLAGNAC|     2.67| 4.18|
# |          FENOUILLET|     2.63| 4.17|
# |            LEGUEVIN|     2.62| 4.46|
# |  PORTET SUR GARONNE|     2.76| 4.19|
# | VILLENEUVE TOLOSANE|     2.69| 4.38|
# |       TOURNEFEUILLE|     2.55| 4.54|
# |           BEAUZELLE|     2.79| 4.36|
# |              PIBRAC|     2.52| 4.55|
# |RAMONVILLE-SAINT-...|     2.85| 4.59|
# |        CORNEBARRIEU|     2.63| 4.03|
# |               MURET|     2.63| 4.25|
# |  PLAISANCE DU TOUCH|     2.57| 4.43|
# |               BALMA|     2.93| 4.64|
# |    VIEILLE TOULOUSE|      2.0| 4.68|
# |          ESCALQUENS|     2.68| 4.55|
# |             CUGNAUX|     2.74| 4.18|
# |    CASTANET TOLOSAN|     2.67| 4.56|
# |             L UNION|     2.64| 4.56|
# |          SAINT-JEAN|     2.58| 4.62|
# |   QUINT-FONSEGRIVES|     2.69| 4.38|
# +--------------------+---------+-----+
# only showing top 20 rows

# %%
# Converting to a Pandas DataFrame for better visualization or further analysis:
avg_rooms_per_city_pd = avg_rooms_per_city.toPandas()
print(avg_rooms_per_city_pd.round(2))
# Out:
#                         City  APARTMENT  HOUSE
# 0                    BLAGNAC       2.67   4.18
# 1                 FENOUILLET       2.63   4.17
# 2                   LEGUEVIN       2.62   4.46
# 3         PORTET SUR GARONNE       2.76   4.19
# 4        VILLENEUVE TOLOSANE       2.69   4.38
# 5              TOURNEFEUILLE       2.55   4.54
# 6                  BEAUZELLE       2.79   4.36
# 7                     PIBRAC       2.52   4.55
# 8      RAMONVILLE-SAINT-AGNE       2.85   4.59
# 9               CORNEBARRIEU       2.63   4.03
# 10                     MURET       2.63   4.25
# 11        PLAISANCE DU TOUCH       2.57   4.43
# 12                     BALMA       2.93   4.64
# 13          VIEILLE TOULOUSE       2.00   4.68
# 14                ESCALQUENS       2.68   4.55
# 15                   CUGNAUX       2.74   4.18
# 16          CASTANET TOLOSAN       2.67   4.56
# 17                   L UNION       2.64   4.56
# 18                SAINT-JEAN       2.58   4.62
# 19         QUINT-FONSEGRIVES       2.69   4.38
# 20                 COLOMIERS       2.81   4.44
# 21        AUZEVILLE-TOLOSANE       2.96   4.62
# 22  SAINT-ORENS-DE-GAMEVILLE       2.68   4.59
# 23                    LABEGE       3.05   4.31
# 24                  TOULOUSE       2.53   4.09
# 25                AUCAMVILLE       2.52   4.11

# %% [markdown]
# # Variation of prices for Houses vs Apartments

# %% [markdown]
# To analyze the variation of prices for houses versus apartments depending on the area for the previous year, we will follow a series of steps involving filtering your data, grouping by residence type and area, and then calculating statistical measures or trends that reflect performance.

# %% [markdown]
# **Calculate Average Price by Year and Residence Type**

# %%
from pyspark.sql.functions import to_date, year, avg

# Extract the year from SaleDate for yearly analysis
real_estate_df = real_estate_df.withColumn("Year", year("SaleDate"))

price_by_year_df = real_estate_df.groupBy("Year", "ResidenceType")\
                                 .agg(avg("Price").alias("AvgPrice"))\
                                 .orderBy("Year", "ResidenceType")

# %%
price_by_year_pd = price_by_year_df.toPandas()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.lineplot(data=price_by_year_pd, x="Year", y="AvgPrice", hue="ResidenceType")
plt.title('Yearly Average Price Trend for Houses vs. Apartments')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.legend(title='Residence Type')
plt.show()

# %% [markdown]
# Due to the difference between price of House vs Apartment, we've decided to compute the year over year percentage change in average price.

# %% [markdown]
# ### Year-over-Year Change

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import lag, col

# Assuming price_by_year_df is already defined as shown in previous examples

# Define a window partitioned by ResidenceType, ordered by Year
windowSpec = Window.partitionBy("ResidenceType").orderBy("Year")

# Add a column with the previous year's average price
price_by_year_df = price_by_year_df.withColumn("PrevYearAvgPrice", lag("AvgPrice").over(windowSpec))

# Calculate the year-over-year percentage change
price_by_year_df = price_by_year_df.withColumn("PctChange",
                                                (col("AvgPrice") - col("PrevYearAvgPrice")) / col("PrevYearAvgPrice") * 100)

# Filter out the first row for each residence type since the percentage change can't be calculated for the first year in the dataset
price_by_year_df = price_by_year_df.filter(col("PctChange").isNotNull())

# %% [markdown]
# ### Visualization of Percentage Change

# %%
# Convert to Pandas DataFrame for visualization
price_pct_change_pd = price_by_year_df.toPandas()

# Visualization
plt.figure(figsize=(14, 7))
sns.lineplot(data=price_pct_change_pd, x="Year", y="PctChange", hue="ResidenceType", marker="o")
plt.title('Year-over-Year Percentage Change in Average Prices')
plt.xlabel('Year')
plt.ylabel('Percentage Change')
plt.axhline(0, color='grey', lw=0.5)
plt.legend(title='Residence Type')
plt.show()

# %% [markdown]
# **Highlighting the Observation**
#
# Based on the data analysis, we've observed that while apartment prices can decrease, house prices tend to maintain a trend of increasing by more than 1% annually, suggesting that house values tend to keep pace with or exceed inflation, thereby preserving or increasing their value over time.
#
# **Specific Trends in Selected Years**
#
# In 2016, apartment prices were significantly higher than those of houses. However, from 2017 to 2019, apartment prices fluctuated between 0% and -2% year-over-year change, indicating a period of stagnation or slight decline. In contrast, house prices during the same period (specifically in 2016 and 2017) showed a more robust growth, staying between 3% and 1%, which underscores the resilience of house values during those years.

# %% [markdown]
# # Forecast
# When analyzing the real estate market dynamics, it's crucial to differentiate between houses and apartments due to their distinct market behaviors. As observed, houses tend to exhibit a steady increase in value, often aligning with or surpassing inflation rates, thereby representing a stable investment.
#
# Apartments, while potentially offering higher initial returns, can show greater price volatility. To gain deeper insights and guide investment decisions, we forecast future price trends for both houses and apartments across different cities.
#
# **Forecasting Approach:**
#
#
# *   Data Preparation
# *   Model Selection: ML Approach thanks to Facebook Prophet library.
# *   Forecasting Execution
# *   Visualization & Analysis

# %% [markdown]
# ## Data Preparation

# %%
from pyspark.sql.functions import to_date, year, avg

# Assuming real_estate_df is your Spark DataFrame with real estate data
real_estate_df = real_estate_df.withColumn("SaleDate", to_date("SaleDate", "yyyy-MM-dd"))
real_estate_df = real_estate_df.withColumn("Year", year("SaleDate"))

# Aggregate average price by Year, City, and ResidenceType
price_by_year_city_df = real_estate_df.groupBy("Year", "City", "ResidenceType")\
                                      .agg(avg("Price").alias("AvgPrice"))\
                                      .orderBy("Year", "City", "ResidenceType")

# %% [markdown]
# ## Model Selection

# %% [markdown]
# For this example, we choose Facebook Prophet due to its robustness and simplicity for time series forecasting.

# %%
from prophet import Prophet

# %% [markdown]
# ## Forecasting Execution

# %%
# Placeholder for looping through each city and residence type
forecast_results = []

for city in price_by_year_city_df.select("City").distinct().collect():
    for residence_type in ["HOUSE", "APARTMENT"]:
        # Filter data for the current city and residence type
        city_type_df = price_by_year_city_df.filter((price_by_year_city_df.City == city.City) &
                                                    (price_by_year_city_df.ResidenceType == residence_type))

        # Convert to Pandas DataFrame
        city_type_pd = city_type_df.toPandas()

        # Rename columns for Prophet
        city_type_pd.rename(columns={'Year': 'ds', 'AvgPrice': 'y'}, inplace=True)
        city_type_pd['ds'] = pd.to_datetime(city_type_pd['ds'].astype(str) + '-01-01')

# %% [markdown]
# ### Forecasting House Price

# %%
# Assuming the loop setup as provided
for city in price_by_year_city_df.select("City").distinct().collect():
    for residence_type in ["HOUSE"]:
        # Filtering and preparation code remains the same...

        # Instantiate and fit the model
        model = Prophet()
        model.fit(city_type_pd[['ds', 'y']])

        # Make a future DataFrame for 5 years and predict
        future = model.make_future_dataframe(periods=5, freq='Y')
        forecast = model.predict(future)

        # Extract relevant forecast information (e.g., yearly trend) and append to results
        forecast_results.append({'City': city.City, 'ResidenceType': residence_type, 'Forecast': forecast[['ds', 'yhat']].tail(5)})
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/jxuwtksq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/tmnvevce.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64548', 'data', 'file=/tmp/tmpyo7zigde/jxuwtksq.json', 'init=/tmp/tmpyo7zigde/tmnvevce.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelrtsn7p7f/prophet_model-20240211230922.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/mj2igcbg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/788fbbkx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87122', 'data', 'file=/tmp/tmpyo7zigde/mj2igcbg.json', 'init=/tmp/tmpyo7zigde/788fbbkx.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model97crg24k/prophet_model-20240211230923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/i2oypm21.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/gvfsr4pe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58980', 'data', 'file=/tmp/tmpyo7zigde/i2oypm21.json', 'init=/tmp/tmpyo7zigde/gvfsr4pe.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelnhrw6l8e/prophet_model-20240211230923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ipbkanab.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/4wpi38x5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87477', 'data', 'file=/tmp/tmpyo7zigde/ipbkanab.json', 'init=/tmp/tmpyo7zigde/4wpi38x5.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelwtcpmoan/prophet_model-20240211230923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/1xfg143t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/05fw907t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76330', 'data', 'file=/tmp/tmpyo7zigde/1xfg143t.json', 'init=/tmp/tmpyo7zigde/05fw907t.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model_41wsmbe/prophet_model-20240211230923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/qwpjxbps.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/p0nckhkp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35660', 'data', 'file=/tmp/tmpyo7zigde/qwpjxbps.json', 'init=/tmp/tmpyo7zigde/p0nckhkp.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelh2fdjm13/prophet_model-20240211230923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ec57l1_p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ipxp74h9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28317', 'data', 'file=/tmp/tmpyo7zigde/ec57l1_p.json', 'init=/tmp/tmpyo7zigde/ipxp74h9.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelzellx1ui/prophet_model-20240211230923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/0a2_snqd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/p0ztj_3o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63630', 'data', 'file=/tmp/tmpyo7zigde/0a2_snqd.json', 'init=/tmp/tmpyo7zigde/p0ztj_3o.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelqkd6cwv3/prophet_model-20240211230924.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/mf852z0z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/1rcn80ym.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81215', 'data', 'file=/tmp/tmpyo7zigde/mf852z0z.json', 'init=/tmp/tmpyo7zigde/1rcn80ym.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelclhap1at/prophet_model-20240211230924.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/f789s2ue.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/73yw6aoj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45291', 'data', 'file=/tmp/tmpyo7zigde/f789s2ue.json', 'init=/tmp/tmpyo7zigde/73yw6aoj.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modell8map21o/prophet_model-20240211230924.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/7m95wrr6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/49vlht5p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9274', 'data', 'file=/tmp/tmpyo7zigde/7m95wrr6.json', 'init=/tmp/tmpyo7zigde/49vlht5p.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelu9o4l2jr/prophet_model-20240211230924.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/cm4wb0ac.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/bj1w3iwm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76541', 'data', 'file=/tmp/tmpyo7zigde/cm4wb0ac.json', 'init=/tmp/tmpyo7zigde/bj1w3iwm.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelkatmvw37/prophet_model-20240211230924.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/b48es3t9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/el4u265o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22584', 'data', 'file=/tmp/tmpyo7zigde/b48es3t9.json', 'init=/tmp/tmpyo7zigde/el4u265o.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modellygu_h03/prophet_model-20240211230924.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/wpxgwnpp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/hmidtit0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51551', 'data', 'file=/tmp/tmpyo7zigde/wpxgwnpp.json', 'init=/tmp/tmpyo7zigde/hmidtit0.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelbzmeg6ts/prophet_model-20240211230924.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/6a9jgxa6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/v3_ima59.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39772', 'data', 'file=/tmp/tmpyo7zigde/6a9jgxa6.json', 'init=/tmp/tmpyo7zigde/v3_ima59.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelqk95pzs8/prophet_model-20240211230925.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/_8zdjj9n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/5hf2bvox.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88146', 'data', 'file=/tmp/tmpyo7zigde/_8zdjj9n.json', 'init=/tmp/tmpyo7zigde/5hf2bvox.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeldoekvurp/prophet_model-20240211230925.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/7l0bfte8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/wlcg7l4f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34726', 'data', 'file=/tmp/tmpyo7zigde/7l0bfte8.json', 'init=/tmp/tmpyo7zigde/wlcg7l4f.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model9oqxt_m5/prophet_model-20240211230925.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/pwelcrnn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/mefwbsmh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70182', 'data', 'file=/tmp/tmpyo7zigde/pwelcrnn.json', 'init=/tmp/tmpyo7zigde/mefwbsmh.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelbphpp12g/prophet_model-20240211230925.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/nsw5a1f9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/gx5_7mv9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89789', 'data', 'file=/tmp/tmpyo7zigde/nsw5a1f9.json', 'init=/tmp/tmpyo7zigde/gx5_7mv9.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelfr5n5uvj/prophet_model-20240211230925.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/9tgcjk24.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/1msbwnuq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12071', 'data', 'file=/tmp/tmpyo7zigde/9tgcjk24.json', 'init=/tmp/tmpyo7zigde/1msbwnuq.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model0a4mqmnu/prophet_model-20240211230925.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/6ny0v2z7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/othai4fp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96535', 'data', 'file=/tmp/tmpyo7zigde/6ny0v2z7.json', 'init=/tmp/tmpyo7zigde/othai4fp.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelm5wu9z7s/prophet_model-20240211230926.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/_gf07z2k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/2jktln9e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18095', 'data', 'file=/tmp/tmpyo7zigde/_gf07z2k.json', 'init=/tmp/tmpyo7zigde/2jktln9e.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelnxefuwa4/prophet_model-20240211230926.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/0kn54qpm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/3v3yyh0_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48083', 'data', 'file=/tmp/tmpyo7zigde/0kn54qpm.json', 'init=/tmp/tmpyo7zigde/3v3yyh0_.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelafkxonqa/prophet_model-20240211230926.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/pdgowxwv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ymndh4i4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15656', 'data', 'file=/tmp/tmpyo7zigde/pdgowxwv.json', 'init=/tmp/tmpyo7zigde/ymndh4i4.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelxuqh85vb/prophet_model-20240211230926.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/hr06w3tv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/umsvfye2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73839', 'data', 'file=/tmp/tmpyo7zigde/hr06w3tv.json', 'init=/tmp/tmpyo7zigde/umsvfye2.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelbrgyksew/prophet_model-20240211230926.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/vjszccsq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/x3jxz2hy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84487', 'data', 'file=/tmp/tmpyo7zigde/vjszccsq.json', 'init=/tmp/tmpyo7zigde/x3jxz2hy.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelfo90x3jn/prophet_model-20240211230926.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ### Forecasting Apartment Price

# %%
# Assuming the loop setup as provided
for city in price_by_year_city_df.select("City").distinct().collect():
    for residence_type in ["APARTMENT"]:
        # Filtering and preparation code remains the same...

        # Instantiate and fit the model
        model = Prophet()
        model.fit(city_type_pd[['ds', 'y']])

        # Make a future DataFrame for 5 years and predict
        future = model.make_future_dataframe(periods=5, freq='Y')
        forecast = model.predict(future)

        # Extract relevant forecast information (e.g., yearly trend) and append to results
        forecast_results.append({'City': city.City, 'ResidenceType': residence_type, 'Forecast': forecast[['ds', 'yhat']].tail(5)})
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/l2amebk0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/fbdln7nz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2376', 'data', 'file=/tmp/tmpyo7zigde/l2amebk0.json', 'init=/tmp/tmpyo7zigde/fbdln7nz.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model7lo6_snv/prophet_model-20240211230937.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/4z7v3rzy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/gbgiljc6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89887', 'data', 'file=/tmp/tmpyo7zigde/4z7v3rzy.json', 'init=/tmp/tmpyo7zigde/gbgiljc6.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelj47wlquc/prophet_model-20240211230937.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/mhxo2hdy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/tl7fueuc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57659', 'data', 'file=/tmp/tmpyo7zigde/mhxo2hdy.json', 'init=/tmp/tmpyo7zigde/tl7fueuc.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelqrwgj3r6/prophet_model-20240211230938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/bydppoj3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/t8xhl8jr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19942', 'data', 'file=/tmp/tmpyo7zigde/bydppoj3.json', 'init=/tmp/tmpyo7zigde/t8xhl8jr.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model0dxpp83n/prophet_model-20240211230938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ajmnn1jk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/awx_tlr5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3703', 'data', 'file=/tmp/tmpyo7zigde/ajmnn1jk.json', 'init=/tmp/tmpyo7zigde/awx_tlr5.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model2mh07rke/prophet_model-20240211230938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/73kvxd3y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/m50lx56q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74932', 'data', 'file=/tmp/tmpyo7zigde/73kvxd3y.json', 'init=/tmp/tmpyo7zigde/m50lx56q.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model382h3goy/prophet_model-20240211230938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/in3lb5gj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ttbph8eu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23704', 'data', 'file=/tmp/tmpyo7zigde/in3lb5gj.json', 'init=/tmp/tmpyo7zigde/ttbph8eu.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelha3cd_hy/prophet_model-20240211230938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/vfp3o6p2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/43nltq9j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29674', 'data', 'file=/tmp/tmpyo7zigde/vfp3o6p2.json', 'init=/tmp/tmpyo7zigde/43nltq9j.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modell7kx9yp1/prophet_model-20240211230938.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/vawphubp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/civk_x_g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92835', 'data', 'file=/tmp/tmpyo7zigde/vawphubp.json', 'init=/tmp/tmpyo7zigde/civk_x_g.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelami5f1cc/prophet_model-20240211230939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/p26lseuj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/lwkffdxn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13311', 'data', 'file=/tmp/tmpyo7zigde/p26lseuj.json', 'init=/tmp/tmpyo7zigde/lwkffdxn.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelw7dbbwfh/prophet_model-20240211230939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/kid8lgai.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/_0ikj7a8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70691', 'data', 'file=/tmp/tmpyo7zigde/kid8lgai.json', 'init=/tmp/tmpyo7zigde/_0ikj7a8.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model5xo3k3de/prophet_model-20240211230939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/zy5asqgf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ap7r59ql.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36886', 'data', 'file=/tmp/tmpyo7zigde/zy5asqgf.json', 'init=/tmp/tmpyo7zigde/ap7r59ql.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelic0cdig4/prophet_model-20240211230939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/o4sleqi9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/z50ljoe8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60281', 'data', 'file=/tmp/tmpyo7zigde/o4sleqi9.json', 'init=/tmp/tmpyo7zigde/z50ljoe8.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelp_hpmqv5/prophet_model-20240211230939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/q7n_ml06.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/8pyls9oq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32885', 'data', 'file=/tmp/tmpyo7zigde/q7n_ml06.json', 'init=/tmp/tmpyo7zigde/8pyls9oq.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelm5ua7av_/prophet_model-20240211230939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/crnixlj5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/dz96_wbk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85590', 'data', 'file=/tmp/tmpyo7zigde/crnixlj5.json', 'init=/tmp/tmpyo7zigde/dz96_wbk.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modellqf5desy/prophet_model-20240211230939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/rl23hfoi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/s0ofx2v9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97040', 'data', 'file=/tmp/tmpyo7zigde/rl23hfoi.json', 'init=/tmp/tmpyo7zigde/s0ofx2v9.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelqutiy_h9/prophet_model-20240211230940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/p8b0qsqb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/auzrq5qy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45471', 'data', 'file=/tmp/tmpyo7zigde/p8b0qsqb.json', 'init=/tmp/tmpyo7zigde/auzrq5qy.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model_voodgfz/prophet_model-20240211230940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/iof1izk2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/dew84wvm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57855', 'data', 'file=/tmp/tmpyo7zigde/iof1izk2.json', 'init=/tmp/tmpyo7zigde/dew84wvm.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model1vz9hx7i/prophet_model-20240211230940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/l2xvygf4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/2jkyr1vo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83577', 'data', 'file=/tmp/tmpyo7zigde/l2xvygf4.json', 'init=/tmp/tmpyo7zigde/2jkyr1vo.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelbr2adah3/prophet_model-20240211230940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ffkkv2ps.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/tg7f0lb2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43531', 'data', 'file=/tmp/tmpyo7zigde/ffkkv2ps.json', 'init=/tmp/tmpyo7zigde/tg7f0lb2.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model3ibixjm6/prophet_model-20240211230940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/fkz8p_js.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/dzlfnr5y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25705', 'data', 'file=/tmp/tmpyo7zigde/fkz8p_js.json', 'init=/tmp/tmpyo7zigde/dzlfnr5y.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelu7wo_ycd/prophet_model-20240211230940.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/vmesl4k6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/zivasw8p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94377', 'data', 'file=/tmp/tmpyo7zigde/vmesl4k6.json', 'init=/tmp/tmpyo7zigde/zivasw8p.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelhinl_x3g/prophet_model-20240211230941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/2w4uw6bc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/t2ngeyqp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41662', 'data', 'file=/tmp/tmpyo7zigde/2w4uw6bc.json', 'init=/tmp/tmpyo7zigde/t2ngeyqp.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modell3d_8xjz/prophet_model-20240211230941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/g785i8pd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/h9bcsvgr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5562', 'data', 'file=/tmp/tmpyo7zigde/g785i8pd.json', 'init=/tmp/tmpyo7zigde/h9bcsvgr.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelspute4dz/prophet_model-20240211230941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/t8x4v99r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ap354fmk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4484', 'data', 'file=/tmp/tmpyo7zigde/t8x4v99r.json', 'init=/tmp/tmpyo7zigde/ap354fmk.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelun29cy64/prophet_model-20240211230941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/it79zunk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/z50f_g08.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89683', 'data', 'file=/tmp/tmpyo7zigde/it79zunk.json', 'init=/tmp/tmpyo7zigde/z50f_g08.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelj7msxrq4/prophet_model-20240211230941.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ## Collecting and Visualizing Results
# After collecting the forecast results in forecast_results, we will convert this list to a DataFrame for easier manipulation and visualization.
#
# Then, we are going to proceed to visualize the top 3 cities with the highest forecasted price increase.
#
# ### Visualization of Top 3 Cities with the Highest Forecasted Price Increase

# %% [markdown]
# **Adjusting Data Transformation and Forecast Extraction**

# %%
# Placeholder for looping through each city and residence type
forecast_results = []

for city_row in price_by_year_city_df.select("City").distinct().collect():
    city = city_row.City
    for residence_type in ["HOUSE", "APARTMENT"]:
        # Filter data for the current city and residence type
        city_type_df = price_by_year_city_df.filter((price_by_year_city_df.City == city) &
                                                    (price_by_year_city_df.ResidenceType == residence_type))

        # Convert to Pandas DataFrame
        city_type_pd = city_type_df.toPandas()

        # Rename columns for Prophet
        city_type_pd.rename(columns={'Year': 'ds', 'AvgPrice': 'y'}, inplace=True)
        city_type_pd['ds'] = pd.to_datetime(city_type_pd['ds'].astype(str) + '-01-01')

        # Check if there are enough data points for fitting the model
        if len(city_type_pd) >= 2:
            # Instantiate and fit the model
            model = Prophet()
            model.fit(city_type_pd[['ds', 'y']])

            # Make a future DataFrame for 5 years and predict
            future = model.make_future_dataframe(periods=5, freq='Y')
            forecast = model.predict(future)

            # Extract relevant forecast information (e.g., yearly trend) and append to results
            forecast_results.append({'City': city, 'ResidenceType': residence_type, 'Forecast': forecast[['ds', 'yhat']].tail(5)})
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/g4_i0xu0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/g4rzufgo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90800', 'data', 'file=/tmp/tmpyo7zigde/g4_i0xu0.json', 'init=/tmp/tmpyo7zigde/g4rzufgo.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelg_e1q964/prophet_model-20240211232825.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/m_x3rhnh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/26lu94t2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44166', 'data', 'file=/tmp/tmpyo7zigde/m_x3rhnh.json', 'init=/tmp/tmpyo7zigde/26lu94t2.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model756dhoy9/prophet_model-20240211232831.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/qlp4bser.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/vw1f5kf_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68660', 'data', 'file=/tmp/tmpyo7zigde/qlp4bser.json', 'init=/tmp/tmpyo7zigde/vw1f5kf_.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeljjjh_pck/prophet_model-20240211232833.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/suebrm6u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/wb40u05g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72058', 'data', 'file=/tmp/tmpyo7zigde/suebrm6u.json', 'init=/tmp/tmpyo7zigde/wb40u05g.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelpucf7901/prophet_model-20240211232836.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ztngtd33.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/f6j4y7em.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10095', 'data', 'file=/tmp/tmpyo7zigde/ztngtd33.json', 'init=/tmp/tmpyo7zigde/f6j4y7em.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelfm80eg6d/prophet_model-20240211232839.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/4crdjbck.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/770yfrid.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87202', 'data', 'file=/tmp/tmpyo7zigde/4crdjbck.json', 'init=/tmp/tmpyo7zigde/770yfrid.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model51e9pf17/prophet_model-20240211232847.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/dwxlblz8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/bwx5no6a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30568', 'data', 'file=/tmp/tmpyo7zigde/dwxlblz8.json', 'init=/tmp/tmpyo7zigde/bwx5no6a.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelqvf10aua/prophet_model-20240211232849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/t3f2z4e5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/66zwewo7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18913', 'data', 'file=/tmp/tmpyo7zigde/t3f2z4e5.json', 'init=/tmp/tmpyo7zigde/66zwewo7.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelk5kiuglp/prophet_model-20240211232852.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:28:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/smlf3tiu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/6th2__p_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30548', 'data', 'file=/tmp/tmpyo7zigde/smlf3tiu.json', 'init=/tmp/tmpyo7zigde/6th2__p_.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelwbe7z3k5/prophet_model-20240211232854.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:28:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/d9uu84nh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/6xpd5jl6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65894', 'data', 'file=/tmp/tmpyo7zigde/d9uu84nh.json', 'init=/tmp/tmpyo7zigde/6xpd5jl6.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelkimf4fnp/prophet_model-20240211232902.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/p_7qbt62.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/k3j00_e5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8182', 'data', 'file=/tmp/tmpyo7zigde/p_7qbt62.json', 'init=/tmp/tmpyo7zigde/k3j00_e5.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelbdl7ndfm/prophet_model-20240211232904.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/un7tpdoa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/rhkye4yf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51176', 'data', 'file=/tmp/tmpyo7zigde/un7tpdoa.json', 'init=/tmp/tmpyo7zigde/rhkye4yf.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelhd4cqrlz/prophet_model-20240211232913.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ei10qeix.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/jwjw_38n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53846', 'data', 'file=/tmp/tmpyo7zigde/ei10qeix.json', 'init=/tmp/tmpyo7zigde/jwjw_38n.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelv82d7zbq/prophet_model-20240211232916.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/rpj9c5ed.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/9uzsu759.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20784', 'data', 'file=/tmp/tmpyo7zigde/rpj9c5ed.json', 'init=/tmp/tmpyo7zigde/9uzsu759.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model_ejx1v_z/prophet_model-20240211232918.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ccvfw436.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/qxz9btmv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75473', 'data', 'file=/tmp/tmpyo7zigde/ccvfw436.json', 'init=/tmp/tmpyo7zigde/qxz9btmv.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeleycifttn/prophet_model-20240211232927.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/apdcif_z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/bqjtjqyt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40157', 'data', 'file=/tmp/tmpyo7zigde/apdcif_z.json', 'init=/tmp/tmpyo7zigde/bqjtjqyt.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelwm8qne52/prophet_model-20240211232929.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/vpifw77v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/_tdttpum.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96509', 'data', 'file=/tmp/tmpyo7zigde/vpifw77v.json', 'init=/tmp/tmpyo7zigde/_tdttpum.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelic60dnly/prophet_model-20240211232931.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/530mvhqi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/27qo6bwr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77623', 'data', 'file=/tmp/tmpyo7zigde/530mvhqi.json', 'init=/tmp/tmpyo7zigde/27qo6bwr.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeltdnbq1lf/prophet_model-20240211232939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/tkv5ttm_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/cqn5kmk1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66004', 'data', 'file=/tmp/tmpyo7zigde/tkv5ttm_.json', 'init=/tmp/tmpyo7zigde/cqn5kmk1.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model4xu9i_q1/prophet_model-20240211232942.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/xukqtz60.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/_1l4t5nd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26375', 'data', 'file=/tmp/tmpyo7zigde/xukqtz60.json', 'init=/tmp/tmpyo7zigde/_1l4t5nd.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeltrw8sw6y/prophet_model-20240211232951.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/d2g8gqri.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/t31thm1k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55089', 'data', 'file=/tmp/tmpyo7zigde/d2g8gqri.json', 'init=/tmp/tmpyo7zigde/t31thm1k.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model1kru8sgi/prophet_model-20240211232954.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/2vcd3t7n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/fpi0k92a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95403', 'data', 'file=/tmp/tmpyo7zigde/2vcd3t7n.json', 'init=/tmp/tmpyo7zigde/fpi0k92a.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model1d9bcflk/prophet_model-20240211232956.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/r61h8i9s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/a88uul3l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94937', 'data', 'file=/tmp/tmpyo7zigde/r61h8i9s.json', 'init=/tmp/tmpyo7zigde/a88uul3l.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelabkyicwe/prophet_model-20240211232959.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:29:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:29:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/q4n4v9tf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/sxbd2otg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8910', 'data', 'file=/tmp/tmpyo7zigde/q4n4v9tf.json', 'init=/tmp/tmpyo7zigde/sxbd2otg.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeli4s197jz/prophet_model-20240211233003.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/wq5laowo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/abmm870h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87507', 'data', 'file=/tmp/tmpyo7zigde/wq5laowo.json', 'init=/tmp/tmpyo7zigde/abmm870h.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelp90867sv/prophet_model-20240211233006.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ctol250p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/a898ne4i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6656', 'data', 'file=/tmp/tmpyo7zigde/ctol250p.json', 'init=/tmp/tmpyo7zigde/a898ne4i.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelbtda_dhh/prophet_model-20240211233014.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/dstap2uy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/g937iwar.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56943', 'data', 'file=/tmp/tmpyo7zigde/dstap2uy.json', 'init=/tmp/tmpyo7zigde/g937iwar.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelf4dfy1iy/prophet_model-20240211233022.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/1zu98pit.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/g0jzwyel.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12734', 'data', 'file=/tmp/tmpyo7zigde/1zu98pit.json', 'init=/tmp/tmpyo7zigde/g0jzwyel.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model402oq9ve/prophet_model-20240211233027.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/bq1xaqkm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/4nlmiax3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72696', 'data', 'file=/tmp/tmpyo7zigde/bq1xaqkm.json', 'init=/tmp/tmpyo7zigde/4nlmiax3.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelet37upki/prophet_model-20240211233030.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/10udoxav.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ezivv9x0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62428', 'data', 'file=/tmp/tmpyo7zigde/10udoxav.json', 'init=/tmp/tmpyo7zigde/ezivv9x0.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model16ykh_8s/prophet_model-20240211233032.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/s94osa0p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/wa_pv4w6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75824', 'data', 'file=/tmp/tmpyo7zigde/s94osa0p.json', 'init=/tmp/tmpyo7zigde/wa_pv4w6.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelwauwu5ai/prophet_model-20240211233034.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/yqko8vp6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/upimao64.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8741', 'data', 'file=/tmp/tmpyo7zigde/yqko8vp6.json', 'init=/tmp/tmpyo7zigde/upimao64.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model4_cqafqg/prophet_model-20240211233036.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/n4okr31k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/w4d3g9v9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49632', 'data', 'file=/tmp/tmpyo7zigde/n4okr31k.json', 'init=/tmp/tmpyo7zigde/w4d3g9v9.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelwvylintj/prophet_model-20240211233038.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/qsmd66js.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/lp9hmo71.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84216', 'data', 'file=/tmp/tmpyo7zigde/qsmd66js.json', 'init=/tmp/tmpyo7zigde/lp9hmo71.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeldg3ggntc/prophet_model-20240211233040.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/0bqeok64.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/3br6rk_4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92670', 'data', 'file=/tmp/tmpyo7zigde/0bqeok64.json', 'init=/tmp/tmpyo7zigde/3br6rk_4.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelh9wmi944/prophet_model-20240211233049.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/gkmk9qgl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/iua9d7ei.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21433', 'data', 'file=/tmp/tmpyo7zigde/gkmk9qgl.json', 'init=/tmp/tmpyo7zigde/iua9d7ei.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeltxp2_1sw/prophet_model-20240211233051.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/0l88rsb7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/n1j7ew4o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75066', 'data', 'file=/tmp/tmpyo7zigde/0l88rsb7.json', 'init=/tmp/tmpyo7zigde/n1j7ew4o.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelox06tw77/prophet_model-20240211233053.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/m7432oqo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/6awnszl9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68242', 'data', 'file=/tmp/tmpyo7zigde/m7432oqo.json', 'init=/tmp/tmpyo7zigde/6awnszl9.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelog7g3yi7/prophet_model-20240211233056.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/nruvzkn9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/99tpytj3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83491', 'data', 'file=/tmp/tmpyo7zigde/nruvzkn9.json', 'init=/tmp/tmpyo7zigde/99tpytj3.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model1ua9k8bf/prophet_model-20240211233059.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:30:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:30:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/dn1lawyh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/5t7xfxz2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71303', 'data', 'file=/tmp/tmpyo7zigde/dn1lawyh.json', 'init=/tmp/tmpyo7zigde/5t7xfxz2.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeljokmjird/prophet_model-20240211233101.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/3es86r6x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/6859cp5h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29141', 'data', 'file=/tmp/tmpyo7zigde/3es86r6x.json', 'init=/tmp/tmpyo7zigde/6859cp5h.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelmyp32xzz/prophet_model-20240211233103.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/fxcolq54.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/k3cpreb4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40900', 'data', 'file=/tmp/tmpyo7zigde/fxcolq54.json', 'init=/tmp/tmpyo7zigde/k3cpreb4.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modele792pks_/prophet_model-20240211233105.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/peenfc4h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/adj9ycjr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64993', 'data', 'file=/tmp/tmpyo7zigde/peenfc4h.json', 'init=/tmp/tmpyo7zigde/adj9ycjr.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelm1lqui3n/prophet_model-20240211233107.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/b5p7riiw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/4xgy9guc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76277', 'data', 'file=/tmp/tmpyo7zigde/b5p7riiw.json', 'init=/tmp/tmpyo7zigde/4xgy9guc.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelqomnss0_/prophet_model-20240211233110.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/fd273bzq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/g9eux1cn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81250', 'data', 'file=/tmp/tmpyo7zigde/fd273bzq.json', 'init=/tmp/tmpyo7zigde/g9eux1cn.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelh4qcdu1u/prophet_model-20240211233118.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/mib_4yqz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/47r4kvks.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38300', 'data', 'file=/tmp/tmpyo7zigde/mib_4yqz.json', 'init=/tmp/tmpyo7zigde/47r4kvks.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelqb3l272f/prophet_model-20240211233120.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 2.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/ch28noz_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/cr7qcf_7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17443', 'data', 'file=/tmp/tmpyo7zigde/ch28noz_.json', 'init=/tmp/tmpyo7zigde/cr7qcf_7.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_model352t9np8/prophet_model-20240211233122.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/7ave9apd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/j4o35qqy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4647', 'data', 'file=/tmp/tmpyo7zigde/7ave9apd.json', 'init=/tmp/tmpyo7zigde/j4o35qqy.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeliyp1l8tc/prophet_model-20240211233131.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/zo7j2dlu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/zyv4kof5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43220', 'data', 'file=/tmp/tmpyo7zigde/zo7j2dlu.json', 'init=/tmp/tmpyo7zigde/zyv4kof5.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeldb1enm5j/prophet_model-20240211233139.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/no25gn05.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/7g39czsp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60429', 'data', 'file=/tmp/tmpyo7zigde/no25gn05.json', 'init=/tmp/tmpyo7zigde/7g39czsp.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modeletu1ogzs/prophet_model-20240211233147.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 3.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/z2jk0220.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyo7zigde/28c3jhhl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53023', 'data', 'file=/tmp/tmpyo7zigde/z2jk0220.json', 'init=/tmp/tmpyo7zigde/28c3jhhl.json', 'output', 'file=/tmp/tmpyo7zigde/prophet_modelpivo6fby/prophet_model-20240211233156.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:31:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:31:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# **Visualization for Apartments Over the Next Year**

# %%
# Filter forecast_df for apartments
apartment_forecast_df = forecast_df[forecast_df['ResidenceType'] == 'APARTMENT']

# Calculate the average price in 2019 for apartments
avg_price_2019 = apartment_forecast_df[apartment_forecast_df['Date'].dt.year == 2019]['ForecastedPrice'].mean()

# Calculate the forecasted price for 2020
forecast_price_2020 = apartment_forecast_df[apartment_forecast_df['Date'].dt.year == 2020][['City', 'ForecastedPrice']]

# Calculate the percentage change between forecasted price for 2020 and average price in 2019
forecast_price_2020['PriceChangePercentage'] = (forecast_price_2020['ForecastedPrice'] / avg_price_2019 - 1) * 100

# Sort the DataFrame by price change percentage in descending order
sorted_forecasts = forecast_price_2020.sort_values(by='PriceChangePercentage', ascending=False)

# Highlight the top 3 cities with the highest percentage change
top_3_highest_price_change = sorted_forecasts.head(3)

# Display the DataFrame
print("Top 3 Cities with the Highest Percentage Change in Forecasted Apartment Prices:")
print(top_3_highest_price_change)
# Out:
# Top 3 Cities with the Highest Percentage Change in Forecasted Apartment Prices:
#                   City  ForecastedPrice  PriceChangePercentage
# 76              PIBRAC    390510.265303             157.495547
# 191  QUINT-FONSEGRIVES    275440.277088              81.620437
# 66           BEAUZELLE    204545.500765              34.873678

# %%
# Filter forecast_df for apartments in Pibrac, Quint-Fonsegrives, and Beauzelle
cities_to_plot = ['PIBRAC', 'QUINT-FONSEGRIVES', 'BEAUZELLE']
cities_forecast = forecast_df[(forecast_df['ResidenceType'] == 'APARTMENT') & (forecast_df['City'].isin(cities_to_plot))]

# Plotting forecasted prices over time for the selected cities
plt.figure(figsize=(10, 6))
for city in cities_to_plot:
    city_data = cities_forecast[cities_forecast['City'] == city]
    plt.plot(city_data['Date'], city_data['ForecastedPrice'], label=city)

plt.title('Forecasted Prices Over Time for Selected Cities')
plt.xlabel('Date')
plt.ylabel('Forecasted Price')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ** Analyzing the forecasted prices over time for the selected cities: **
#
# The plot shows the trend of forecasted apartment prices from 2020 to 2024 for Pibrac, Quint-Fonsegrives, and Beauzelle.
# Overall, we observe a general upward trend in forecasted prices for all three cities, with fluctuations in certain periods.
#
#
# Pibrac experienced the highest increase in prices, reaching a peak in 2021, followed by a slight decrease towards 2024.
# Quint-Fonsegrives and Beauzelle also saw increases in prices, albeit with less volatility compared to Pibrac.
#
#
# It's important to note that the forecasted prices are subject to change based on various factors such as market conditions and economic trends.

# %% [markdown]
# **Visualization for Houses Over the Next Year**

# %%
# Filter forecast_df for houses
house_forecast_df = forecast_df[forecast_df['ResidenceType'] == 'HOUSE']

# Calculate the average price in 2019 for houses
avg_price_2019_house = house_forecast_df[house_forecast_df['Date'].dt.year == 2019]['ForecastedPrice'].mean()

# Calculate the forecasted price for 2020 for houses
forecast_price_2020_house = house_forecast_df[house_forecast_df['Date'].dt.year == 2020][['City', 'ForecastedPrice']]

# Calculate the percentage change between forecasted price for 2020 and average price in 2019 for houses
forecast_price_2020_house['PriceChangePercentage'] = (forecast_price_2020_house['ForecastedPrice'] / avg_price_2019_house - 1) * 100

# Sort the DataFrame by price change percentage in descending order for houses
sorted_forecasts_house = forecast_price_2020_house.sort_values(by='PriceChangePercentage', ascending=False)

# Display the top 3 cities with the highest percentage change for houses
print("Top 3 Cities with the Highest Percentage Change in Forecasted House Prices:")
print(sorted_forecasts_house.head(3))
# Out:
# Top 3 Cities with the Highest Percentage Change in Forecasted House Prices:
#                          City  ForecastedPrice  PriceChangePercentage
# 131          VIEILLE TOULOUSE    584185.352390             100.515865
# 186         QUINT-FONSEGRIVES    395907.369900              35.891303
# 216  SAINT-ORENS-DE-GAMEVILLE    359619.280799              23.435774

# %%
# Get the top 3 cities with the highest percentage change for houses
top_3_cities_house = sorted_forecasts_house.head(3)['City'].tolist()

# Filter forecast_df for houses in the top 3 cities
house_cities_forecast = house_forecast_df[house_forecast_df['City'].isin(top_3_cities_house)]

# Plotting forecasted prices over time for the top 3 cities with the highest percentage change for houses
plt.figure(figsize=(10, 6))
for city in top_3_cities_house:
    city_data_house = house_cities_forecast[house_cities_forecast['City'] == city]
    plt.plot(city_data_house['Date'], city_data_house['ForecastedPrice'], label=city)

plt.title('Forecasted House Prices Over Time for Top 3 Cities')
plt.xlabel('Date')
plt.ylabel('Forecasted Price')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# It seems that there is a downward trend in forecasted house prices from 2020 to 2021, followed by an upward trend from 2021 onwards for both Vieille Toulouse and Saint-Orens-de-Gameville. Specifically, Vieille Toulouse experiences a decrease in forecasted house prices from around 800 to 600 and then an increase to around 880. Similarly, Saint-Orens-de-Gameville follows a similar pattern.
#
#
# Overall, the analysis suggests that although there may have been a temporary decline in forecasted house prices in 2021, there is a subsequent recovery and upward trajectory in prices in the following years. This indicates resilience in the housing market of these cities and potential opportunities for investment.
